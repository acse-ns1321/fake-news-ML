# %% [markdown]
# # SPEECH AND EMOTION RECOGNITION
#
# Build a projet using librosa, soundfile and sklearn using an MLP Classifier.
#
# **The project :**
# - recognizes emotions from sound files
# - loads data, extract features from it
# - splits into training and test sets
# - initializes an MLPClassifier
# - train the model
# - find the accuracy of the model
#
# **The Dataset :**
# - RAVDESS dataset (Ryerson Audio-Visual Database of Emotional Speech and Song)
# The file contains
# - 7356 files
# - rated by 247 individuals
# - ten times each on emotional validity, intensity, and genuineness
# - Original data set is 24.8GB from 24 actors
# - Current data set is lowered the sampled rate

# %%
# !pip install librosa soundfile numpy sklearn pyaudio
# Out:
# ...
#      -------------------------------------- 213.1/213.1 KB 4.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 689.4/689.4 KB 8.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 377.5/377.5 KB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------- 323.4/323.4 KB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 2.4/2.4 MB 8.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 56.3/56.3 KB 2.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.0/14.0 MB 7.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 23.2/23.2 MB 8.7 MB/s eta 0:00:00
# ...

# %%
# ------------------------------------------------
# Import the necessary files
# ------------------------------------------------

# library to analyze sound and music
import librosa

# library to import soundfiles
import soundfile

# File organization packages
import os, glob, pickle

# Import numpy 
import numpy as np

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Define the function to Extract Features**
#
# The features we need to extract are:
#
# - mfcc : Mel Frequency Cepstral Coefficient, represents the short-term power spectrum of a sound
# - chroma : Pertains to the 12 different pitch classes
# - mel features : Mel Spectrogram Frequency

# %%
def extract_features(filename, mfcc, chroma, mel):
    # Function that is used to extract 3 features\using librosa and get the mean value
    # Collect all the values and store them in a numpy array
    
    # Extract sound from the filename
    # Using with-as so it’s automatically closed once we’re done
    with soundfile.SoundFile(file_name) as sound_file:
        
        # Read the soundfile
        X = sound_file.read(dtype= 'float32')

        # Get sample rate from the soundfile
        sample_rate = sound_file.samplerate

        # Empty array to store the results
        result = np.array([])

        # Test for the 3 features
        if chroma:
            stft = mp.abs(librosa.stft(X))

        if mfcc:
            mfccs = np.mean(librosa.feature.mfcc(y = X, sr = sample_rate, n_mfcc = 40).T, axis = 0)

        # Update results
        result = n.hstack((result, mfccs))

        if chroma:
            chroma = np.mean(librosa.feature.chroma_stft(S = stft, sr = sample_rate).T, axis = 0)

        # Update results
        result = n.hstack((result,chroma))

        if mel:
            mel = np.mean(librosa.feaature.melspectrogram(X, sr = sample_rate).T, axis = 0)

        # Update results
        result = np.hstack((result, mel))

        return result

# %%
# -------------------------------------------------
# DICTIONARY TO STORE EMOTIONS
# -------------------------------------------------

emotions = { '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'}

observed_emotions = {'calm', 'happy', 'fearful', 'disgust'}
# Out:
#   File "C:\Users\NIRANJ~1\AppData\Local\Temp/ipykernel_6680/3748574636.py", line 5
#     emtions =
#               ^
# SyntaxError: invalid syntax
